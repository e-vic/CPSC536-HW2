# %% [markdown]
# Here I am writing text

# %%
import Pkg
Pkg.add("Images")
Pkg.add("TestImages")
Pkg.add("Colors")
Pkg.add("FileIO")
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`
#   Resolving package versions...
# No Changes to `~/.julia/environments/v1.5/Project.toml`
# No Changes to `~/.julia/environments/v1.5/Manifest.toml`

# %%
Pkg.add("ImageMagick")
Pkg.add("QuartzImageIO")
Pkg.add("OMETIFF")
# Out:
#   Resolving package versions...
#   Installed Libtiff_jll ───── v4.1.0+1
#   Installed ImageMagick_jll ─ v6.9.10-12+3
#   Installed Zstd_jll ──────── v1.4.5+1
#   Installed JpegTurbo_jll ─── v2.0.1+2
#   Installed ImageMagick ───── v1.1.6
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [6218d12a] + ImageMagick v1.1.6
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [6218d12a] + ImageMagick v1.1.6
#   [c73af94c] + ImageMagick_jll v6.9.10-12+3
#   [aacddb02] + JpegTurbo_jll v2.0.1+2
#   [89763e89] + Libtiff_jll v4.1.0+1
#   [3161d3a3] + Zstd_jll v1.4.5+1
#   Resolving package versions...
#   Installed QuartzImageIO ─ v0.7.3
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [dca85d43] + QuartzImageIO v0.7.3
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [dca85d43] + QuartzImageIO v0.7.3
#   Resolving package versions...
#   Installed ConstructionBase ──── v1.0.0
#   Installed XML2_jll ──────────── v2.9.10+2
#   Installed Libiconv_jll ──────── v1.16.0+6
#   Installed Unitful ───────────── v1.4.1
#   Installed DocStringExtensions ─ v0.8.3
#   Installed EzXML ─────────────── v1.1.0
#   Installed DataStructures ────── v0.17.20
#   Installed OMETIFF ───────────── v0.3.8
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [2d0ec36b] + OMETIFF v0.3.8
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [34da2185] - Compat v3.20.0
#   [187b0558] + ConstructionBase v1.0.0
#   [864edb3b] ↓ DataStructures v0.18.7 ⇒ v0.17.20
#   [ffbed154] + DocStringExtensions v0.8.3
#   [8f5d6c58] + EzXML v1.1.0
#   [94ce4f54] + Libiconv_jll v1.16.0+6
#   [2d0ec36b] + OMETIFF v0.3.8
#   [1986cc42] + Unitful v1.4.1
#   [02c8fc9c] + XML2_jll v2.9.10+2
#   [8bb1440f] - DelimitedFiles

# %%
using Images, TestImages, Colors, FileIO
using ImageIO; ImageMagick; QuartzImageIO; OMETIFF
# Out:
# UndefVarError: ImageMagick not defined
#
# Stacktrace:
#  [1] top-level scope
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091
#  [3] execute_code(::String, ::String) at /Users/naomi/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:27
#  [4] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /Users/naomi/.julia/packages/IJulia/rWZ9e/src/execute_request.jl:86
#  [5] #invokelatest#1 at ./essentials.jl:710 [inlined]
#  [6] invokelatest at ./essentials.jl:709 [inlined]
#  [7] eventloop(::ZMQ.Socket) at /Users/naomi/.julia/packages/IJulia/rWZ9e/src/eventloop.jl:8
#  [8] (::IJulia.var"#15#18")() at ./task.jl:356

# %%
climbing_img_fromfile = Images.load("./climbing_slab.jpg")
# Out:
# 460×760 Array{RGBX{N0f8},2} with eltype RGBX{Normed{UInt8,8}}:
#  RGBX{N0f8}(1.0,1.0,1.0)        …  RGBX{N0f8}(0.412,0.412,0.412)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.533,0.533,0.533)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.678,0.678,0.678)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.761,0.761,0.761)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.765,0.765,0.765)
#  RGBX{N0f8}(1.0,1.0,1.0)        …  RGBX{N0f8}(0.737,0.737,0.737)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.733,0.733,0.733)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.745,0.745,0.745)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.745,0.745,0.745)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.702,0.702,0.702)
#  RGBX{N0f8}(1.0,1.0,1.0)        …  RGBX{N0f8}(0.675,0.675,0.675)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.706,0.706,0.706)
#  RGBX{N0f8}(1.0,1.0,1.0)           RGBX{N0f8}(0.773,0.773,0.773)
#  ⋮                              ⋱
#  RGBX{N0f8}(0.09,0.09,0.09)        RGBX{N0f8}(0.545,0.545,0.545)
#  RGBX{N0f8}(0.118,0.118,0.118)     RGBX{N0f8}(0.576,0.576,0.576)
#  RGBX{N0f8}(0.145,0.145,0.145)  …  RGBX{N0f8}(0.553,0.553,0.553)
#  RGBX{N0f8}(0.153,0.153,0.153)     RGBX{N0f8}(0.482,0.482,0.482)
#  RGBX{N0f8}(0.157,0.157,0.157)     RGBX{N0f8}(0.463,0.463,0.463)
#  RGBX{N0f8}(0.173,0.173,0.173)     RGBX{N0f8}(0.49,0.49,0.49)
#  RGBX{N0f8}(0.212,0.212,0.212)     RGBX{N0f8}(0.463,0.463,0.463)
#  RGBX{N0f8}(0.247,0.247,0.247)  …  RGBX{N0f8}(0.388,0.388,0.388)
#  RGBX{N0f8}(0.282,0.282,0.282)     RGBX{N0f8}(0.4,0.4,0.4)
#  RGBX{N0f8}(0.286,0.286,0.286)     RGBX{N0f8}(0.459,0.459,0.459)
#  RGBX{N0f8}(0.294,0.294,0.294)     RGBX{N0f8}(0.525,0.525,0.525)
#  RGBX{N0f8}(0.302,0.302,0.302)     RGBX{N0f8}(0.557,0.557,0.557)

# %%
Pkg.add("ImageIO")
# Out:
#   Resolving package versions...
#   Installed Artifacts ─── v1.3.0
#   Installed libpng_jll ── v1.6.37+5
#   Installed Zlib_jll ──── v1.2.11+17
#   Installed ImageIO ───── v0.3.0
#   Installed CEnum ─────── v0.4.1
#   Installed PNGFiles ──── v0.3.1
#   Installed JLLWrappers ─ v1.1.1
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [82e4d734] + ImageIO v0.3.0
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [56f22d72] + Artifacts v1.3.0
#   [fa961155] + CEnum v0.4.1
#   [82e4d734] + ImageIO v0.3.0
#   [692b3bcd] + JLLWrappers v1.1.1
#   [f57f5aa1] + PNGFiles v0.3.1
#   [83775a58] + Zlib_jll v1.2.11+17
#   [b53b4c65] + libpng_jll v1.6.37+5

# %%
image = testimage("lighthouse")
# Out:
# ┌ Info: Precompiling QuartzImageIO [dca85d43-d64c-5e67-8c65-017450d5d020]
# └ @ Base loading.jl:1278
# ┌ Warning: Module ColorVectorSpace with build ID 1939923977358 is missing from the cache.
# │ This may mean ColorVectorSpace [c3611d14-8923-5661-9e6a-0046d554d3a4] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# 512×768 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.361,0.486,0.6)    …  RGB{N0f8}(0.349,0.49,0.529)
#  RGB{N0f8}(0.361,0.486,0.6)       RGB{N0f8}(0.369,0.498,0.58)
#  RGB{N0f8}(0.376,0.514,0.624)     RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.365,0.498,0.62)      RGB{N0f8}(0.345,0.478,0.588)
#  RGB{N0f8}(0.365,0.498,0.627)     RGB{N0f8}(0.349,0.486,0.596)
#  RGB{N0f8}(0.369,0.502,0.635)  …  RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.38,0.518,0.635)      RGB{N0f8}(0.365,0.502,0.612)
#  RGB{N0f8}(0.369,0.502,0.635)     RGB{N0f8}(0.376,0.502,0.616)
#  RGB{N0f8}(0.357,0.502,0.627)     RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.349,0.49,0.62)       RGB{N0f8}(0.373,0.498,0.604)
#  RGB{N0f8}(0.373,0.518,0.643)  …  RGB{N0f8}(0.353,0.494,0.592)
#  RGB{N0f8}(0.388,0.533,0.659)     RGB{N0f8}(0.361,0.498,0.608)
#  RGB{N0f8}(0.38,0.525,0.643)      RGB{N0f8}(0.376,0.514,0.624)
#  ⋮                             ⋱
#  RGB{N0f8}(0.204,0.169,0.137)  …  RGB{N0f8}(0.157,0.188,0.204)
#  RGB{N0f8}(0.169,0.133,0.118)     RGB{N0f8}(0.169,0.196,0.224)
#  RGB{N0f8}(0.149,0.122,0.11)      RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.153,0.125,0.114)     RGB{N0f8}(0.176,0.216,0.239)
#  RGB{N0f8}(0.188,0.165,0.141)     RGB{N0f8}(0.231,0.271,0.294)
#  RGB{N0f8}(0.31,0.298,0.263)   …  RGB{N0f8}(0.255,0.302,0.333)
#  RGB{N0f8}(0.486,0.498,0.443)     RGB{N0f8}(0.231,0.29,0.318)
#  RGB{N0f8}(0.663,0.682,0.627)     RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.702,0.745,0.678)     RGB{N0f8}(0.267,0.31,0.353)
#  RGB{N0f8}(0.459,0.486,0.447)     RGB{N0f8}(0.184,0.22,0.247)
#  RGB{N0f8}(0.443,0.467,0.439)  …  RGB{N0f8}(0.18,0.208,0.22)
#  RGB{N0f8}(0.0,0.0,0.0)           RGB{N0f8}(0.0,0.0,0.0)
# ┌ Info: Skipping precompilation since __precompile__(false). Importing QuartzImageIO [dca85d43-d64c-5e67-8c65-017450d5d020].
# └ @ Base loading.jl:1034
